# %%
#importing libaries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.fft import fft, fftfreq, fftshift

# %%
bearing_signals = pd.read_csv('bearing_signals.csv')
bearing_classes = pd.read_csv('bearing_classes.csv', delimiter=';')

# %%
bearing_signals = bearing_signals.drop(['bearing_1_id','experiment_id'], 1)
bearing_signals.rename(columns={'bearing_2_id': 'bearing_id'}, inplace=True)
bearing_signals.head(2)
# Out:
#    bearing_id  timestamp      a1_x      a1_y      a1_z      a2_x      a2_y  \
# 0           1   0.000000  0.113269  0.149706 -0.110275 -0.186030  0.194450
# 1           1   0.000333 -0.367713 -0.228832  0.177821  0.285992  0.002226
# 2           1   0.000667  0.113269  0.149706 -0.398371 -0.091625  0.002226
# 3           1   0.001000 -0.175320 -0.228832 -0.110275  0.285992  0.002226
# 4           1   0.001333 -0.079124  0.055072 -0.110275  0.191588  0.002226
#
#        a2_z  rpm   hz         w
# 0  0.454299  0.0  0.0  0.000006
# 1 -0.043930  0.0  0.0  0.000243
# 2  0.454299  0.0  0.0  0.000369
# 3  0.255007  0.0  0.0  0.000520
# 4  0.255007  0.0  0.0  0.000175

# %% [markdown]
# Data analysing and cleaning

# %%
bearing_signals.isnull().sum()
# Out:
# bearing_id    0
# timestamp     0
# a1_x          0
# a1_y          0
# a1_z          0
# a2_x          0
# a2_y          0
# a2_z          0
# rpm           0
# hz            0
# w             0
# dtype: int64

# %%
bearing_signals.describe()
# Out:
#          bearing_id     timestamp          a1_x          a1_y          a1_z  \
# count  1.026570e+07  1.026570e+07  1.026570e+07  1.026570e+07  1.026570e+07
# mean   5.658897e+01  1.556797e+01 -2.200731e-01 -4.832596e-02 -5.254890e-02
# std    3.231361e+01  9.425589e+00  1.824082e+00  1.450662e+00  1.768919e+00
# min    1.000000e+00  0.000000e+00 -1.604771e+01 -1.887183e+01 -1.633967e+01
# 25%    2.900000e+01  7.638000e+00 -1.041087e+00 -6.073697e-01 -8.785304e-01
# 50%    5.600000e+01  1.527633e+01 -1.753203e-01 -3.956274e-02 -1.424326e-02
# 75%    8.500000e+01  2.291433e+01  5.942500e-01  5.282442e-01  8.500439e-01
# max    1.120000e+02  5.549967e+01  1.560087e+01  1.614294e+01  1.640721e+01
#
#                a2_x          a2_y          a2_z           rpm            hz  \
# count  1.026570e+07  1.026570e+07  1.026570e+07  1.026570e+07  1.026570e+07
# mean  -3.124191e-01 -8.758339e-02  7.102206e-02 -2.760059e+05 -4.600098e+03
# std    2.553113e+00  2.631378e+00  2.700098e+00  4.076958e+07  6.794930e+05
# min   -1.765083e+01 -1.873959e+01 -2.296248e+01 -6.000000e+09 -1.000000e+08
# 25%   -1.602094e+00 -1.247228e+00 -1.040389e+00  4.774536e+02  7.957560e+00
# 50%   -3.748382e-01  2.226305e-03  5.571547e-02  1.285714e+03  2.142857e+01
# 75%    8.524177e-01  8.672333e-01  1.151820e+00  1.487603e+03  2.479339e+01
# max    1.916685e+01  2.249241e+01  2.596364e+01  9.000135e+04  1.500023e+03
#
#                   w
# count  1.026570e+07
# mean   4.629741e-01
# std    4.565080e-01
# min    1.407501e-06
# 25%    4.778236e-02
# 50%    3.781180e-01
# 75%    7.271071e-01
# max    9.393605e+00

# %%
bearing_signals.shape
# Out:
# (10265700, 11)

# %%
bearing_signals.columns.to_list()
# Out:
# ['bearing_id',
#  'timestamp',
#  'a1_x',
#  'a1_y',
#  'a1_z',
#  'a2_x',
#  'a2_y',
#  'a2_z',
#  'rpm',
#  'hz',
#  'w']

# %% [markdown]
# Merging signals tabel with classes tabel

# %%
df = (pd.merge(bearing_signals, bearing_classes, on='bearing_id'))
df.head(2)
# Out:
#    bearing_id  timestamp      a1_x      a1_y      a1_z      a2_x      a2_y  \
# 0           1   0.000000  0.113269  0.149706 -0.110275 -0.186030  0.194450
# 1           1   0.000333 -0.367713 -0.228832  0.177821  0.285992  0.002226
#
#        a2_z  rpm   hz         w  status
# 0  0.454299  0.0  0.0  0.000006       0
# 1 -0.043930  0.0  0.0  0.000243       0

# %% [markdown]
# Calculating metrics per bearing

# %%
df_mean = df.groupby('bearing_id').mean()
df_mean.columns = ['timestamp','a1_x_mean','a1_y_mean','a1_z_mean','a2_x_mean','a2_y_mean','a2_z_mean','rpm_mean','hz_mean','w_mean','status']
df_mean = df_mean.drop(['timestamp'], 1)
df_mean = df_mean.drop(40)

# %%
df_max = df.groupby('bearing_id').max()
df_max = df_max.drop(40)
df_max = df_max.drop(['timestamp','rpm','hz','status'], 1)
df_max.columns = ['a1_x_max','a1_y_max','a1_z_max','a2_x_max','a2_y_max','a2_z_max','w_max']

# %%
df_min = df.groupby('bearing_id').min()
df_min = df_min.drop(40)
df_min = df_min.drop(['timestamp','rpm','hz','w','status'], 1)
df_min.columns = ['a1_x_min','a1_y_min','a1_z_min','a2_x_min','a2_y_min','a2_z_min']

# %%
df_min_range = df.groupby('bearing_id').min()
df_min_range = df_min_range.drop(40)
df_min_range = df_min_range.drop(['timestamp','rpm','hz','status'], 1)

# %%
df_max_range = df.groupby('bearing_id').max()
df_max_range = df_max_range.drop(40)
df_max_range = df_max_range.drop(['timestamp','rpm','hz','status'], 1)

# %%
df_range = df_max_range.subtract(df_min_range, fill_value=0)
df_range.columns = ['a1_x_range','a1_y_range','a1_z_range','a2_x_range','a2_y_range','a2_z_range','w_range']
df_range.head(2)
# Out:
#             a1_x_range  a1_y_range  a1_z_range  a2_x_range  a2_y_range  \
# bearing_id
# 1            16.738155    9.936622   17.861935   18.692052   17.876810
# 2            15.006622    9.558084   16.421456   17.748009   16.723468
# 3            15.583800    9.558084   16.421456   21.712990   18.645705
# 4            12.505518    9.558084   15.173042   17.653605   15.666237
# 5            14.718033   10.882967   17.189712   20.580138   18.549593
# ...                ...         ...         ...         ...         ...
# 108          15.583800   13.627367   20.166701   21.996202   15.474013
# 109          14.429444   10.788333   19.014318   14.349454   12.686769
# 110          19.624044   10.504429   19.494477   16.331944   13.071216
# 111          16.064781    9.084912   19.110350   14.632667   12.013985
# 112          17.411529   10.599064   20.262733   15.859923   14.512894
#
#             a2_z_range   w_range
# bearing_id
# 1            22.021738  1.679265
# 2            20.028821  1.907449
# 3            19.132008  2.132677
# 4            18.932716  1.877710
# 5            17.039445  1.578119
# ...                ...       ...
# 108          23.516426  1.887597
# 109          21.124925  1.754798
# 110          21.423863  1.707395
# 111          17.438028  1.799548
# 112          31.388451  1.723047
#
# [111 rows x 7 columns]

# %%
df_master = (pd.merge(df_mean, df_range, on='bearing_id'))
df_master = (pd.merge(df_master, df_min, on='bearing_id'))
df_master = (pd.merge(df_master, df_max, on='bearing_id'))
df_master.head(2)
# Out:
#             a1_x_mean  a1_y_mean  a1_z_mean  a2_x_mean  a2_y_mean  a2_z_mean  \
# bearing_id
# 1           -0.176971  -0.001740  -0.035361   0.114590   0.023329   0.250710
# 2           -0.174032  -0.007636  -0.053353  -0.178986   0.024936   0.194061
# 3           -0.172328  -0.002343  -0.039898  -0.121842   0.036149   0.183881
# 4           -0.149644  -0.000549  -0.037679  -0.119574   0.030838   0.200699
# 5           -0.146438   0.015268  -0.026678  -0.080799   0.034042   0.206547
# ...               ...        ...        ...        ...        ...        ...
# 108         -0.145112   0.026677   0.120057  -0.225940   0.069918   0.219440
# 109         -0.124200   0.077907   0.219025  -0.229740   0.099719   0.184505
# 110         -0.132581   0.080428   0.213349  -0.209128   0.117938   0.079041
# 111         -0.126273   0.090689   0.221793  -0.150227   0.124992   0.029792
# 112         -0.153778   0.086890   0.231944  -0.179616   0.123758   0.264096
#
#                rpm_mean    hz_mean    w_mean  status  ...   a2_x_min  \
# bearing_id                                            ...
# 1           1082.423656  18.040394  0.419961       0  ... -10.004077
# 2           1074.981634  17.916361  0.501160       0  ...  -9.437651
# 3           1149.927038  19.165451  0.513051       0  ... -12.080972
# 4           1127.538630  18.792311  0.539426       0  ... -10.004077
# 5           1037.216452  17.286941  0.353715       0  ... -11.325737
# ...                 ...        ...       ...     ...  ...        ...
# 108          952.405287  15.873421  0.387498       1  ... -11.136929
# 109         1000.562215  16.676037  0.262752       1  ...  -7.266352
# 110         1073.939895  17.898998  0.302760       1  ...  -8.682417
# 111          987.802878  16.463381  0.299101       1  ...  -7.455161
# 112          980.042404  16.334040  0.351847       1  ...  -8.493608
#
#             a2_y_min   a2_z_min   a1_x_max  a1_y_max   a1_z_max   a2_x_max  \
# bearing_id
# 1          -8.647843 -10.207810   7.327991  5.638507   9.204820   8.687975
# 2          -7.975060 -11.104623   7.424187  4.881431   8.340533   8.310358
# 3          -8.455619 -11.204268   7.231794  5.449238   8.052437   9.632018
# 4          -7.782836 -11.104623   5.981243  4.881431   8.148469   7.649527
# 5          -8.840067  -7.816309   6.750813  6.206314   8.340533   9.254401
# ...              ...        ...        ...       ...        ...        ...
# 108        -6.917829 -12.101081   7.231794  6.679486   9.204820  10.859274
# 109        -6.052822 -10.805685   7.520383  4.786797   9.012756   7.083102
# 110        -6.052822  -9.709580  10.598665  4.313624  10.069107   7.649527
# 111        -5.283927  -8.812767   8.867131  4.313624   9.877043   7.177506
# 112        -7.206165 -16.784437   9.059524  4.881431   9.973075   7.366315
#
#              a2_y_max   a2_z_max     w_max
# bearing_id
# 1            9.228967  11.813929  1.679266
# 2            8.748408   8.924198  1.907451
# 3           10.190086   7.927740  2.132678
# 4            7.883401   7.828094  1.877711
# 5            9.709526   9.223136  1.578121
# ...               ...        ...       ...
# 108          8.556184  11.415345  1.887599
# 109          6.633946  10.319241  1.754799
# 110          7.018394  11.714283  1.707396
# 111          6.730058   8.625261  1.799549
# 112          7.306729  14.604013  1.723048
#
# [111 rows x 30 columns]

# %%
df_master.columns.to_list()
# Out:
# ['a1_x_mean',
#  'a1_y_mean',
#  'a1_z_mean',
#  'a2_x_mean',
#  'a2_y_mean',
#  'a2_z_mean',
#  'rpm_mean',
#  'hz_mean',
#  'w_mean',
#  'status',
#  'a1_x_range',
#  'a1_y_range',
#  'a1_z_range',
#  'a2_x_range',
#  'a2_y_range',
#  'a2_z_range',
#  'w_range',
#  'a1_x_min',
#  'a1_y_min',
#  'a1_z_min',
#  'a2_x_min',
#  'a2_y_min',
#  'a2_z_min',
#  'a1_x_max',
#  'a1_y_max',
#  'a1_z_max',
#  'a2_x_max',
#  'a2_y_max',
#  'a2_z_max',
#  'w_max']

# %% [markdown]
# Engeneering frequencies

# %%
df_fft = df
acceleration_cols = ['a1_x','a1_y','a1_z','a2_x','a2_y','a2_z']
acceleration_fft = fft(df[acceleration_cols].values)
df_fft['a1_x_fft'] = abs(acceleration_fft[:,0])
df_fft['a1_y_fft'] = abs(acceleration_fft[:,1])
df_fft['a1_z_fft'] = abs(acceleration_fft[:,2])
df_fft['a2_x_fft'] = abs(acceleration_fft[:,3])
df_fft['a2_y_fft'] = abs(acceleration_fft[:,4])
df_fft['a2_z_fft'] = abs(acceleration_fft[:,5])
df_fft.head()
# Out:
#    bearing_id  timestamp      a1_x      a1_y      a1_z      a2_x      a2_y  \
# 0           1   0.000000  0.113269  0.149706 -0.110275 -0.186030  0.194450
# 1           1   0.000333 -0.367713 -0.228832  0.177821  0.285992  0.002226
# 2           1   0.000667  0.113269  0.149706 -0.398371 -0.091625  0.002226
# 3           1   0.001000 -0.175320 -0.228832 -0.110275  0.285992  0.002226
# 4           1   0.001333 -0.079124  0.055072 -0.110275  0.191588  0.002226
#
#        a2_z  rpm   hz         w  status  a1_x_fft  a1_y_fft  a1_z_fft  \
# 0  0.454299  0.0  0.0  0.000006       0  0.615419  0.768876  0.416851
# 1 -0.043930  0.0  0.0  0.000243       0  0.174436  0.880146  0.314195
# 2  0.454299  0.0  0.0  0.000369       0  0.229504  0.932711  0.116978
# 3  0.255007  0.0  0.0  0.000520       0  0.028798  0.649700  0.355533
# 4  0.255007  0.0  0.0  0.000175       0  0.314494  0.277512  0.076581
#
#    a2_x_fft  a2_y_fft  a2_z_fft
# 0  0.220532  0.416851  0.768876
# 1  0.200896  0.314195  0.880146
# 2  0.795256  0.116978  0.932711
# 3  0.595537  0.355533  0.649700
# 4  0.688839  0.076581  0.277512

# %% [markdown]
# Merging calculated metrics with fequencies per bearing

# %%
df_fft = df_fft.drop(['timestamp', 'a1_x', 'a1_y', 'a1_z', 'a2_x', 'a2_y', 'a2_z', 'rpm', 'hz', 'w', 'status'], 1)
df_fft = df_fft.drop(40)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-18-db25577cb708> in <module>
# ----> 1 df_fft = df_fft.drop(['timestamp', 'a1_x', 'a1_y', 'a1_z', 'a2_x', 'a2_y', 'a2_z', 'rpm', 'hz', 'w', 'status'], 1)
#       2 df_fft = df_fft.drop(40)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4187             else:
#    4188                 new_axis = axis.drop(labels, errors=errors)
# -> 4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#    4191         # Case for non-unique axis
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     310         @wraps(func)
#     311         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 312             return func(*args, **kwargs)
#     313
#     314         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in reindex(self, *args, **kwargs)
#    4174         kwargs.pop("axis", None)
#    4175         kwargs.pop("labels", None)
# -> 4176         return super().reindex(**kwargs)
#    4177
#    4178     def drop(
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    4791             )
#    4792
# -> 4793         self._consolidate_inplace()
#    4794
#    4795         # if all axes that are requested to reindex are equal, then only copy
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _consolidate_inplace(self)
#    5539             self._mgr = self._mgr.consolidate()
#    5540
# -> 5541         self._protect_consolidate(f)
#    5542
#    5543     @final
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _protect_consolidate(self, f)
#    5527         """
#    5528         blocks_before = len(self._mgr.blocks)
# -> 5529         result = f()
#    5530         if len(self._mgr.blocks) != blocks_before:
#    5531             self._clear_item_cache()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in f()
#    5537
#    5538         def f():
# -> 5539             self._mgr = self._mgr.consolidate()
#    5540
#    5541         self._protect_consolidate(f)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in consolidate(self)
#     986         bm = type(self)(self.blocks, self.axes)
#     987         bm._is_consolidated = False
# --> 988         bm._consolidate_inplace()
#     989         return bm
#     990
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _consolidate_inplace(self)
#     991     def _consolidate_inplace(self) -> None:
#     992         if not self.is_consolidated():
# --> 993             self.blocks = tuple(_consolidate(self.blocks))
#     994             self._is_consolidated = True
#     995             self._known_consolidated = True
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _consolidate(blocks)
#    1914     new_blocks: List[Block] = []
#    1915     for (_can_consolidate, dtype), group_blocks in grouper:
# -> 1916         merged_blocks = _merge_blocks(
#    1917             list(group_blocks), dtype=dtype, can_consolidate=_can_consolidate
#    1918         )
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _merge_blocks(blocks, dtype, can_consolidate)
#    1937         # combination of those slices is a slice, too.
#    1938         new_mgr_locs = np.concatenate([b.mgr_locs.as_array for b in blocks])
# -> 1939         new_values = np.vstack([b.values for b in blocks])
#    1940
#    1941         argsort = np.argsort(new_mgr_locs)
#
# <__array_function__ internals> in vstack(*args, **kwargs)
#
# ~\AppData\Roaming\Python\Python38\site-packages\numpy\core\shape_base.py in vstack(tup)
#     280     if not isinstance(arrs, list):
#     281         arrs = [arrs]
# --> 282     return _nx.concatenate(arrs, 0)
#     283
#     284
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# MemoryError: Unable to allocate 1.22 GiB for an array with shape (16, 10265700) and data type float64

# %%
df_fft_mean = df_fft.groupby('bearing_id').mean()
df_fft_mean.columns = ['a1_x_fft_mean', 'a1_y_fft_mean', 'a1_z_fft_mean', 'a2_x_fft_mean', 'a2_y_fft_mean', 'a2_z_fft_mean']
df_fft_mean.head()

# %%
df_fft_max = df_fft.groupby('bearing_id').max()
df_fft_max.columns = ['a1_x_fft_max', 'a1_y_fft_max', 'a1_z_fft_max', 'a2_x_fft_max', 'a2_y_fft_max', 'a2_z_fft_max']
df_fft_max.head()

# %%
df_fft_min = df_fft.groupby('bearing_id').min()
df_fft_min.columns = ['a1_x_fft_min', 'a1_y_fft_min', 'a1_z_fft_min', 'a2_x_fft_min', 'a2_y_fft_min', 'a2_z_fft_min']

# %%
df_fft_min

# %%
df_fft_min_range = df_fft.groupby('bearing_id').min()

# %%
df_fft_min_range

# %%
df_fft_max_range = df_fft.groupby('bearing_id').max()
df_fft_max_range

# %%
df_fft_range = df_fft_max_range.subtract(df_fft_min_range, fill_value=0)
df_fft_range

# %%
df_fft_range.columns = ['a1_x_ff_range', 'a1_y_fft_range', 'a1_z_fft_range', 'a2_x_fft_range', 'a2_y_fft_range', 'a2_z_fft_range']

# %%
df_fft_master = (pd.merge(df_fft_mean, df_fft_range, on='bearing_id'))
df_fft_master = (pd.merge(df_fft_master, df_fft_min, on='bearing_id'))
df_fft_master = (pd.merge(df_fft_master, df_fft_max, on='bearing_id'))
df_fft_master

# %%
df_final_master = (pd.merge(df_master, df_fft_master, on='bearing_id'))

# %%
df_final_master

# %%
df_final_master.info()

# %%
df_rpm_b_68 = df_final_master[df_final_master['bearing_id']==68]
xf = df_rpm_b_68["timestamp"].values
yf = df_rpm_b_68["rpm"].values
plt.plot(xf, yf)
plt.show()
